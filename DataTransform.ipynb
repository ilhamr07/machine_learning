# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#merubah semua nama kolom menjadi huruf kecil
df.columns = df.columns.str.lower()

# %%
#menghapus kolom tiket dan kabin
df.drop(columns=['ticket','cabin'],inplace=True)

# %%
#Ganti nilai Sex jadi 'L' untuk male, 'P' untuk female.

df['sex'].replace({'male':'L','female':'P'},inplace=True)

# %%
#Ambil hanya data penumpang kelas 1 dan usia < 30.

# df

df_filter = df[(df['age'] <30) & (df['pclass']==1)]

df_filter
# Out:
#      passengerid  survived  pclass  \
# 23            24         1       1
# 27            28         0       1
# 34            35         0       1
# 83            84         0       1
# 88            89         1       1
# 97            98         1       1
# 102          103         0       1
# 118          119         0       1
# 136          137         1       1
# 139          140         0       1
# 151          152         1       1
# 290          291         1       1
# 291          292         1       1
# 297          298         0       1
# 305          306         1       1
# 307          308         1       1
# 310          311         1       1
# 311          312         1       1
# 329          330         1       1
# 336          337         0       1
# 341          342         1       1
# 356          357         1       1
# 369          370         1       1
# 370          371         1       1
# 373          374         0       1
# ...

# %%
#ganti nama kolom suvived menjadi selamat

df_filter.rename(columns={
    'survived':'selamat'
},inplace=True)
# Out:
# C:\Users\ilham.renaldyansyah\AppData\Local\Temp\ipykernel_25140\972776112.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter.rename(columns={

# %%
df_filter['selamat2'].replace({1:'selamat',0:'mati'},inplace=True)
# Out:
# C:\Users\ilham.renaldyansyah\AppData\Local\Temp\ipykernel_25140\3418198618.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_filter['selamat2'].replace({1:'selamat',0:'mati'},inplace=True)
# C:\Users\ilham.renaldyansyah\AppData\Local\Temp\ipykernel_25140\3418198618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_filter.head()
# Out:
#     passengerid  selamat  pclass                            name sex   age  \
# 23           24        1       1    Sloper, Mr. William Thompson   L  28.0
# 27           28        0       1  Fortune, Mr. Charles Alexander   L  19.0
# 34           35        0       1         Meyer, Mr. Edgar Joseph   L  28.0
# 83           84        0       1         Carrau, Mr. Francisco M   L  28.0
# 88           89        1       1      Fortune, Miss. Mabel Helen   P  23.0
#
#     sibsp  parch      fare embarked selamat2
# 23      0      0   35.5000        S  selamat
# 27      3      2  263.0000        S     mati
# 34      1      0   82.1708        C     mati
# 83      0      0   47.1000        S     mati
# 88      3      2  263.0000        S  selamat

# %%
test_encode = df_filter.columns(['passengerid','embarked','age','sex'],inde)

# df_encode = pd.DataFrame([test_encode])

# df_encode

test_encode
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 test_encode = df_filter.columns(['passengerid','embarked','age','sex'])
#       3 # df_encode = pd.DataFrame([test_encode])
#       4
#       5 # df_encode
#       7 test_encode
#
# TypeError: 'Index' object is not callable
